# %%
import pandas as pd
import seaborn as sns

# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['2 Understanding your data.ipynb',
#  'AB_NYC_2019.csv',
#  'googleplaystore.csv',
#  'googleplaystore.xlsx',
#  'null value data.csv',
#  'numpy exercise.ipynb',
#  'Profile.pdf',
#  'restaurants.csv',
#  'UCI auto-mpg.csv']

# %%
df = pd.read_csv("AB_NYC_2019.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## 1. Dimension of data?

# %%
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ## 2. How does the data look like?

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# effective or good practise to know about the overall data
df.sample(5)
# Out:
#              id                                               name    host_id  \
# 24414  19659874  Big Private Studio one Subway stop from Manhattan   41578662
# 1497     674692                  A LITTLE PARADISE NEXT TO SUBWAY!    3425965
# 41461  32240603        Sonder | Stock Exchange | Bold 1BR + Lounge  219517861
# 32569  25537456       Prime Location On E. 62nd Street with Garden   56283770
# 42891  33307926      Short term Queen size sofa-bed in living room     747681
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 24414         Lucia               Bronx          Mott Haven  40.81133
# 1497      Francesca              Queens           Ridgewood  40.70719
# 41461  Sonder (NYC)           Manhattan  Financial District  40.70638
# 32569           Lia           Manhattan     Upper East Side  40.76375
# 42891           Pro           Manhattan             Midtown  40.76446
#
# ...

# %% [markdown]
# ## 3. What is the datatype of cols?

# %%
df.info()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ## 4. Are there any missing values?

# %%
df.isna().sum()
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## 5. How does the data look like mathematically?

# %%
# data looks mathmeatically shows descrptive stats of columns
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.890600e+04  4.890600e+04  48906.000000  48906.000000  48906.000000
# mean   1.901287e+07  6.760480e+07     40.728952    -73.952175    152.711324
# std    1.098557e+07  7.860866e+07      0.054529      0.046154    240.128713
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.464662e+06  7.809567e+06     40.690100    -73.983080     69.000000
# 50%    1.967545e+07  3.078463e+07     40.723080    -73.955685    106.000000
# 75%    2.915085e+07  1.074344e+08     40.763120    -73.936283    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48906.000000       48906.000000       38854.000000
# mean         7.031612          23.300454           1.373151
# std         20.512489          44.607175           1.680270
# ...

# %% [markdown]
# ## 6. Are there any duplicate values?

# %%
duplicated = df[df.duplicated()]
duplicated

# showing duplicated value of specfic column
duplicated_ = df[df.duplicated(subset ='name')]         # subset is optional
duplicated_



# Drop duplicate rows
df_no_duplicates = df.drop_duplicates()
(df_no_duplicates)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## 7. How many unique values are there in each column?

# %%
df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df["neighbourhood_group"].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# ## 8. Are there any outliers in the numerical columns?

# %%
sns.boxplot(df["price"])
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(df["availability_365"])
# Out:
# <Axes: ylabel='availability_365'>

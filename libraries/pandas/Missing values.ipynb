# %% [markdown]
# In the field of data-related research, it is very important to handle missing data either by deleting or imputation(handling the missing values with some estimation).

# %% [markdown]
# Different Methods of Dealing With Missing Data
# 1. Deleting the column with missing data
# 2. Deleting the row with missing data
# 3. Filling the Missing Values – Imputation
#
#    (i) Numerical data - use mean
#
#    (ii) categorical data
#        - use mode, median
#        - assign the NaN values their own category
#
#
# 4. Advanced Imputation

# %%
import pandas as pd
import os
os.getcwd()
os.chdir("d:/DOWNLOADS/")
os.listdir()
# Out:
# ['AB_NYC_2019.csv',
#  'googleplaystore.csv',
#  'googleplaystore.xlsx',
#  'Missing values.ipynb',
#  'null value data.csv',
#  'numpy exercise.ipynb',
#  'Profile.pdf',
#  'restaurants.csv',
#  'scholarship.csv',
#  'UCI auto-mpg.csv',
#  'understanding data.ipynb']

# %%
data = pd.read_csv("AB_NYC_2019.csv")
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
data.head()
data.tail()
data.sample(10)
# Out:
#              id                                               name    host_id  \
# 30934  23964318       Private Bedroom-Upper East Side-Central Park  180212824
# 2466    1241905                Bedroom in big sunny loft (& roof!)    2873394
# 26762  21249716  MidtownWest  Home close to Times Square & Broa...    4144536
# 41043  31909623   Wyndham Midtown 45 New York City 1 BR Apt w/View   96086378
# 19866  15926847  Super spacious & sunny 1-bedroom Fort Greene Apt.   19966776
# 31248  24267385             Sonder | 116 John | Charming 1BR + Gym   12243051
# 32607  25590224    Private furnished room near Columbia University     673215
# 4059    2577467                1 BR with private bath new building    2920976
# 9801    7543993                        Triplex with private garden    7753501
# 47350  35706068                                   wait until later   35741633
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
data.shape          # tell us rows X coloumns
# Out:
# (48895, 16)

# %% [markdown]
# #### making copy of original data

# %%
df1 = data.copy()

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Detecting the outliers

# %%
df1.shape[0]
df1.columns             # returns the name 
df1.count()
# Out:
# id                                48895
# name                              48879
# host_id                           48895
# host_name                         48874
# neighbourhood_group               48895
# neighbourhood                     48895
# latitude                          48895
# longitude                         48895
# room_type                         48895
# price                             48895
# minimum_nights                    48895
# number_of_reviews                 48895
# last_review                       38843
# reviews_per_month                 38843
# calculated_host_listings_count    48895
# availability_365                  48895
# dtype: int64

# %%
# first way
num_rows = df1.shape[0]
num_missing = num_rows - df1.count()
num_missing
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
import numpy as np
# counting total no of null values
empty_rows = np.count_nonzero(df1.isnull())
empty_rows

# counting total no of null values of a specific column
empty_rows = np.count_nonzero(df1['name'].isnull())
empty_rows
# Out:
# 16

# %%
# second way to get the outliers
df1.isnull().sum()
df1.isna().sum()


# counting the null value in specfic column
df1['name'].isna().sum()
# Out:
# 16

# %% [markdown]
# ## Cleaning the missing data either in respect of rows and columns
# - Recode/ Replace
# - Fill Forward
# - Fill Backward
# - Interpolate
# - drop missing value

# %% [markdown]
# ### Removing column
# ####        ways of removing column
# - df.drop('City', axis=1, inplace=True)
# - del df['Age']
# - city_column = df.pop('City')
# - df = df.drop(['Age', 'City'], axis=1)
#
#
# axis :-
# -   axis=0 ya 'index' → Operation rows pe apply hota hai (vertical direction).
# -    axis=1 ya 'columns' → Operation columns pe apply hota hai (horizontal direction).
#
#
# inplace=True set karta hai, toh original DataFrame hi change ho jaata hai, aur koi naya DataFrame return nahi hota.

# %%
df1 = data.drop("last_review",axis =1)

# %%
df1.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1.shape
# Out:
# (48895, 15)

# %% [markdown]
# #### removing rows

# %%
# dropped nulll values rows
df2 = data.dropna()

# %%
df2.shape
# Out:
# (38821, 16)

# %%
# now there is no null values at all
df2.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ### Filling the missing values - Imputation

# %%
df3 = data.copy()

# %%
df3.shape
# Out:
# (48895, 16)

# %%
df3.head()
df3.head()
df3.sample(10)
# Out:
#              id                                               name    host_id  \
# 29109  22361004                       Manhattan NY Luxurious Hotel  160792280
# 33655  26662052  Beautiful room in Bushwick right next to JMZ t...   19704368
# 42380  32890591  "Color Me Time Sq." Interactive Room in Manhattan  247446830
# 20833  16499824  Upper West 2BR, Met, Lincoln Center, Central Park  108367656
# 10371   7937398          Serene Brownstone Living Close To It All!    6444987
# 23247  18823971                       Gorgeous 1 Bedroom Apartment   13347167
# 45945  35005499      Cozy Corner next to the Empire State Building  263712096
# 31801  24806110                       sunny apartment on the Ocean  187536544
# 18578  14672920                  Lovely stay next to Prospect Park    9030221
# 45085  34517661       370 sq ft King Room near Flatiron & Union Sq  260577152
#
#                   host_name neighbourhood_group              neighbourhood  \
# ...

# %%
df3.describe()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df3.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# #### Numeric data (Use Mean)

# %%
mean = df3["reviews_per_month"].mean()
mean
df3["reviews_per_month"].fillna(mean)
df3
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df3.head()
df3.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df3[df3["number_of_reviews"]==0].head(2)
# Out:
#       id                                 name  host_id  host_name  \
# 2   3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
# 19  7750    Huge 2 BR Upper East  Cental Park    17985       Sing
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 2            Manhattan        Harlem  40.80902  -73.94190     Private room
# 19           Manhattan   East Harlem  40.79685  -73.94872  Entire home/apt
#
#     price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 2     150               3                  0         NaN                NaN
# 19    190               7                  0         NaN                NaN
#
#     calculated_host_listings_count  availability_365
# 2                                1               365
# 19                               2               249

# %%
df3.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# #### Categorical Data (Use mode value)

# %%
df3["last_review"].unique()
# Out:
# array(['2018-10-19', '2019-05-21', nan, ..., '2017-12-23', '2018-01-29',
#        '2018-03-29'], dtype=object)

# %%
df3["last_review"].fillna(df3["last_review"].value_counts().index[0])
# Out:
# 0        2018-10-19
# 1        2019-05-21
# 2        2019-06-23
# 3        2019-07-05
# 4        2018-11-19
#             ...
# 48890    2019-06-23
# 48891    2019-06-23
# 48892    2019-06-23
# 48893    2019-06-23
# 48894    2019-06-23
# Name: last_review, Length: 48895, dtype: object

# %% [markdown]
# #### Categorical data (Use new category)

# %%
df3["last_review"].fillna("Not Reviewed", inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_34904\1568594926.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3["last_review"].fillna("Not Reviewed", inplace = True)

# %%
df3.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews   last_review  \
# ...

# %%
df3.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df3["host_name"].fillna("Unknown")
# Out:
# 0                 John
# 1             Jennifer
# 2            Elisabeth
# 3          LisaRoxanne
# 4                Laura
#              ...
# 48890          Sabrina
# 48891          Marisol
# 48892    Ilgar & Aysel
# 48893              Taz
# 48894       Christophe
# Name: host_name, Length: 48895, dtype: object

# %%
df3.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Forward Fill (ffill()): Propagates the last valid observation forward to fill gaps.
# Uses the next valid observation to fill gaps (bfill())
df3["name"].ffill()
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                          Cozy Entire Floor of Brownstone
# 4         Entire Apt: Spacious Studio/Loft by central park
#                                ...
# 48890      Charming one bedroom - newly renovated rowhouse
# 48891        Affordable room in Bushwick/East Williamsburg
# 48892              Sunny Studio at Historical Neighborhood
# 48893                 43rd St. Time Square-cozy single bed
# 48894    Trendy duplex in the very heart of Hell's Kitchen
# Name: name, Length: 48895, dtype: object

# %%
df3.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df3.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews   last_review  \
# ...

# %% [markdown]
# ### Advanced Imputation

# %%
df5 = data.copy()
df5
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df5.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# interpolation :- mathematical technique hai jo missing ya unknown values ko estimate karne ke liye use hoti hai, basing on known data points ke beech mein. 
# used in specially numerical value
df5["reviews_per_month"].interpolate()
df5
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Handling Duplicate data

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace = True)

# %% [markdown]
# ### Handling duplicate values

# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['AB_NYC_2019.csv',
#  'googleplaystore.csv',
#  'googleplaystore.xlsx',
#  'Missing values.ipynb',
#  'null value data.csv',
#  'numpy exercise.ipynb',
#  'Profile.pdf',
#  'restaurants.csv',
#  'UCI auto-mpg.csv',
#  'understanding data.ipynb']

# %%
df = pd.read_csv("AB_NYC_2019.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.duplicated(["host_id"]).sum()
df.drop_duplicates("host_id",keep= False)
# Out:
#              id                                               name    host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# ...         ...                                                ...        ...
# 48884  36482783        Brooklyn Oasis in the heart of Williamsburg  274307600
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %% [markdown]
# ### Creating own datasets

# %%
students = {
    "name": ['Rishabh', "Yogesh", 'rahul', "sanjay", 'rohit', 'ram','raja', 'manish', 'ravi','Mohit'],
    'marks': {
        "physics" : [82,86,np.nan,56,np.nan,49,64,92,np.nan,81],
        "maths" : [np.nan,70,75,76,83,np.nan,85,63,98,np.nan],
        'Chem':  [46, np.nan, 56,74,92,82,np.nan,54,64,np.nan]  
    }
}

students
# Out:
# {'name': ['Rishabh',
#   'Yogesh',
#   'rahul',
#   'sanjay',
#   'rohit',
#   'ram',
#   'raja',
#   'manish',
#   'ravi',
#   'Mohit'],
#  'marks': {'physics': [82, 86, nan, 56, nan, 49, 64, 92, nan, 81],
#   'maths': [nan, 70, 75, 76, 83, nan, 85, 63, 98, nan],
#   'Chem': [46, nan, 56, 74, 92, 82, nan, 54, 64, nan]}}

# %%
marks_df = pd.DataFrame(students['marks'])
marks_df
name_df = pd.DataFrame(students['name'])
name_df
# Out:
#          0
# 0  Rishabh
# 1   Yogesh
# 2    rahul
# 3   sanjay
# 4    rohit
# 5      ram
# 6     raja
# 7   manish
# 8     ravi
# 9    Mohit

# %%
df = pd.concat([name_df,marks_df], axis = 1)
df
# Out:
#          0  physics  maths  Chem
# 0  Rishabh     82.0    NaN  46.0
# 1   Yogesh     86.0   70.0   NaN
# 2    rahul      NaN   75.0  56.0
# 3   sanjay     56.0   76.0  74.0
# 4    rohit      NaN   83.0  92.0
# 5      ram     49.0    NaN  82.0
# 6     raja     64.0   85.0   NaN
# 7   manish     92.0   63.0  54.0
# 8     ravi      NaN   98.0  64.0
# 9    Mohit     81.0    NaN   NaN

# %%
# now we have data and there is need to detect missing values
num_rows = df.shape[0]
num_missing = num_rows - df.count()
print(num_missing)
df.count()          #  used to count the number of non-null 

# subsitiute
df.isnull().sum()
# Out:
# 0          0
# physics    3
# maths      3
# Chem       3
# dtype: int64
# 0          0
# physics    3
# maths      3
# Chem       3
# dtype: int64

# %%
# copying the data 
df1 = df.copy()
df1
# Out:
#          0  physics  maths  Chem
# 0  Rishabh     82.0    NaN  46.0
# 1   Yogesh     86.0   70.0   NaN
# 2    rahul      NaN   75.0  56.0
# 3   sanjay     56.0   76.0  74.0
# 4    rohit      NaN   83.0  92.0
# 5      ram     49.0    NaN  82.0
# 6     raja     64.0   85.0   NaN
# 7   manish     92.0   63.0  54.0
# 8     ravi      NaN   98.0  64.0
# 9    Mohit     81.0    NaN   NaN

# %%
# now removing the row
df1.dropna()
# Out:
#         0  physics  maths  Chem
# 3  sanjay     56.0   76.0  74.0
# 7  manish     92.0   63.0  54.0

# %%
mean_physics = df['physics'].mean()
df1["physics"].fillna(mean_physics, inplace = True)
df1
# Out:
#          0    physics  maths  Chem
# 0  Rishabh  82.000000    NaN  46.0
# 1   Yogesh  86.000000   70.0   NaN
# 2    rahul  72.857143   75.0  56.0
# 3   sanjay  56.000000   76.0  74.0
# 4    rohit  72.857143   83.0  92.0
# 5      ram  49.000000    NaN  82.0
# 6     raja  64.000000   85.0   NaN
# 7   manish  92.000000   63.0  54.0
# 8     ravi  72.857143   98.0  64.0
# 9    Mohit  81.000000    NaN   NaN

# %%
# now go for maths by using another way
mean_physics = df['maths'].mean()
df1["maths"] = df1["maths"].fillna(mean_physics)
df1
# Out:
#          0    physics      maths  Chem
# 0  Rishabh  82.000000  78.571429  46.0
# 1   Yogesh  86.000000  70.000000   NaN
# 2    rahul  72.857143  75.000000  56.0
# 3   sanjay  56.000000  76.000000  74.0
# 4    rohit  72.857143  83.000000  92.0
# 5      ram  49.000000  78.571429  82.0
# 6     raja  64.000000  85.000000   NaN
# 7   manish  92.000000  63.000000  54.0
# 8     ravi  72.857143  98.000000  64.0
# 9    Mohit  81.000000  78.571429   NaN

# %%
mean = df1['Chem'].mean()
df1["Chem"].fillna(mean,inplace = True)
df1
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_34936\3673227727.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["Chem"].fillna(mean,inplace = True)
#          0    physics      maths       Chem
# 0  Rishabh  82.000000  78.571429  46.000000
# 1   Yogesh  86.000000  70.000000  66.857143
# 2    rahul  72.857143  75.000000  56.000000
# 3   sanjay  56.000000  76.000000  74.000000
# 4    rohit  72.857143  83.000000  92.000000
# 5      ram  49.000000  78.571429  82.000000
# ...

# %%
df1
# Out:
#          0    physics      maths       Chem
# 0  Rishabh  82.000000  78.571429  46.000000
# 1   Yogesh  86.000000  70.000000  66.857143
# 2    rahul  72.857143  75.000000  56.000000
# 3   sanjay  56.000000  76.000000  74.000000
# 4    rohit  72.857143  83.000000  92.000000
# 5      ram  49.000000  78.571429  82.000000
# 6     raja  64.000000  85.000000  66.857143
# 7   manish  92.000000  63.000000  54.000000
# 8     ravi  72.857143  98.000000  64.000000
# 9    Mohit  81.000000  78.571429  66.857143

# %% [markdown]
# # PANDAS
# ### Pandas is an open sources Python liabrary for data analysis. It gives python the ability to work woith spreadsheet like data for fast data loading, manipulation, alignment and merging among other functions
# - Datatypes in Pandas (series, dataframes)

# %% [markdown]
# #####
# - Dataframes reprsents entire spreadsheets or rectangular data
# - series is single column of the dataframe

# %%
import numpy as np
import pandas as pd

# %%
lst  = [1, 2, 3, 4, 5]
array = np.array(lst)
print(array)
print(type(array))
print("*"*25)

# Convert the list to a pandas Series
series = pd.Series(lst)
print(series)
print(type(series))
print("*"*25)

# Convert the list to a pandas DataFrame
dataframe = pd.DataFrame(lst, columns=["Numbers"])
print(dataframe)
print(type(dataframe))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
# *************************
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# *************************
#    Numbers
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# <class 'pandas.core.frame.DataFrame'>

# %%
# help(pd)

# %%
# os liabrary for seeing existing files and folders in the current directory
import os
print(os.getcwd())
os.chdir("d:/DOWNLOADS")
print(os.getcwd())
print(os.listdir())
# Out:
# d:\git\PYTHON\libraries\pandas
# d:\DOWNLOADS
# ['googleplaystore.csv', 'googleplaystore.xlsx', 'numpy exercise.ipynb', 'UCI auto-mpg.csv']

# %%
import pandas as pd
df = pd.read_csv("googleplaystore.csv")          # wow

# %%
df.head(10)             # first 10 rows of the data frame
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.tail()       # returns the last 5 rows of the dataframe
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.to_numpy()  # convert the dataframe to a numpy array
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, ..., 'January 7, 2018', '1.0.0',
#         '4.0.3 and up'],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9, ...,
#         'January 15, 2018', '2.0.0', '4.0.3 and up'],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, ..., 'August 1, 2018', '1.2.4',
#         '4.0.3 and up'],
#        ...,
#        ['Parkinson Exercices FR', 'MEDICAL', nan, ...,
#         'January 20, 2017', '1.0', '2.2 and up'],
#        ['The SCP Foundation DB fr nn5n', 'BOOKS_AND_REFERENCE', 4.5, ...,
#         'January 19, 2015', 'Varies with device', 'Varies with device'],
#        ['iHoroscope - 2018 Daily Horoscope & Astrology', 'LIFESTYLE',
#         4.5, ..., 'July 25, 2018', 'Varies with device',
#         'Varies with device']], dtype=object)

# %%
df.to_excel("googleplaystore.xlsx")  # convert the dataframe to an excel files()
os.getcwd()
os.listdir()
# Out:
# ['googleplaystore.csv', 'googleplaystore.xlsx', 'UCI auto-mpg.csv']

# %%
data = pd.read_csv("googleplaystore.csv")
print(data.head(10),end= "\n\n")
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
data.dtypes  # check the data types of the columns
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data.describe()  # get a summary of the data, including count, mean, std, min, 25%, 50%, 75%, max
data.describe(include="all")  # get a summary of the data, including count, mean, std, min, 25%, 50%, 75%, max for all columns
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
# transpose the data frame
data.T  # transpose the data frame
# Out:
#                                                          0      \
# App             Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                        ART_AND_DESIGN
# Rating                                                     4.1
# Reviews                                                    159
# Size                                                       19M
# Installs                                               10,000+
# Type                                                      Free
# Price                                                        0
# Content Rating                                        Everyone
# Genres                                            Art & Design
# Last Updated                                   January 7, 2018
# Current Ver                                              1.0.0
# Android Ver                                       4.0.3 and up
#
#                                     1      \
# ...

# %%
data
data.sort_index(axis=0, ascending=False)  
data.sort_index(axis=1, ascending=True)
# Out:
#               Android Ver                                                App  \
# 10840  Varies with device      iHoroscope - 2018 Daily Horoscope & Astrology
# 10839  Varies with device                      The SCP Foundation DB fr nn5n
# 10838          2.2 and up                             Parkinson Exercices FR
# 10837          4.1 and up                   Fr. Mike Schmitz Audio Teachings
# 10836          4.1 and up                                   Sya9a Maroc - FR
# ...                   ...                                                ...
# 4              4.4 and up              Pixel Draw - Number Art Coloring Book
# 3              4.2 and up                              Sketch - Draw & Paint
# 2            4.0.3 and up  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 1            4.0.3 and up                                Coloring book moana
# 0            4.0.3 and up     Photo Editor & Candy Camera & Grid & ScrapBook
#
# ...

# %%
data.sort_values(by="Reviews", ascending=False)  # sort the data frame by the "Reviews" column in descending order
# Out:
#                                     App             Category  Rating Reviews  \
# 2989             GollerCepte Live Score               SPORTS     4.2    9992
# 4970       Ad Block REMOVER - NEED ROOT                TOOLS     3.3     999
# 2723                SnipSnap Coupon App             SHOPPING     4.2    9975
# 2705                SnipSnap Coupon App             SHOPPING     4.2    9975
# 3079  US Open Tennis Championships 2018               SPORTS     4.0    9971
# ...                                 ...                  ...     ...     ...
# 7217                          CE-STRONG               FAMILY     NaN       0
# 6492                   Anime Mod for BM  BOOKS_AND_REFERENCE     NaN       0
# 7221                  CE-SETRAM l’Appli   LIBRARIES_AND_DEMO     NaN       0
# 5480           Glanceable Ap Watch Face      PERSONALIZATION     NaN       0
# 4177                    G-NetReport Pro                TOOLS     NaN       0
#
# ...

# %% [markdown]
# ## Selection

# %%
data["Reviews"]  # select the "Reviews" column - getitem
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: object

# %%
data[1:3]
# Out:
#                                                  App        Category  Rating  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
# selecting a row matching a label
print(data.loc[0] ) # get the row with index 1
print(data.head() ) # display the first few rows of the DataFrame

print("*"*25)


# selecting all rows (:) with a select columns labels
data.loc[:, ["App", "Category", "Rating"]]  # select all rows and the "App", "Category", and "Rating" columnsf
# Out:
# App               Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                          ART_AND_DESIGN
# Rating                                                       4.1
# Reviews                                                      159
# Size                                                         19M
# Installs                                                 10,000+
# Type                                                        Free
# Price                                                          0
# Content Rating                                          Everyone
# Genres                                              Art & Design
# Last Updated                                     January 7, 2018
# Current Ver                                                1.0.0
# Android Ver                                         4.0.3 and up
# Name: 0, dtype: object
#                                                  App        Category  Rating  \
# ...

# %%
# For label slicing, both endpoints are included:
data.loc[0:2, ["App", "Category", "Rating"]]  # select rows 0 to 2 and the "App", "Category", and "Rating" columns
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7

# %%
# selecting a single row and column label returns a scalar
data.loc[[0], "App"]  # select the "App" column of the first row
data.loc[0, "App"]
# Out:
# 'Photo Editor & Candy Camera & Grid & ScrapBook'

# %% [markdown]
# ### Selection by Position

# %%
# select via the position of the passed integers
data.iloc[4]

# intger slicing acts similar to Numpy/Python
data.iloc[3:5,0:2]
# Out:
#                                      App        Category
# 3                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN

# %%
# list of intger position locations
data.iloc[[0, 2, 4], [0, 1, 2]]  # select rows 0, 2, and 4 and columns 0, 1, and 2
# Out:
#                                                  App        Category  Rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3

# %%
# for slicing columns explicitly
data.iloc[:, 0:2]  # select all rows and columns 0 and 1

# for slicing rows explicitly
data.iloc[0:2, :]
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
# for getting a value explicitly
data.iloc[1,1]
# For getting fast access to a scalar (equivalent to the prior method):
data.iat[1, 1]  # get the value at row 1 and column 1
# Out:
# 'ART_AND_DESIGN'
